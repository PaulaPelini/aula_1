# %%
import bs4
from bs4 import BeautifulSoup
import requests

# %%
pagina = requests.get('https://www.google.com/search?q=cota%C3%A7%C3%A3o+dolar&rlz=1C1ONGR_pt-PTBR1101&oq=cota%C3%A7%C3%A3o+d&gs_lcrp=EgZjaHJvbWUqDQgAEAAYgwEYsQMYgAQyDQgAEAAYgwEYsQMYgAQyDQgBEAAYgwEYsQMYgAQyBggCEEUYOTINCAMQABiDARixAxiABDIHCAQQABiABDIKCAUQABixAxiABDIHCAYQABiABDIKCAcQABixAxiABDINCAgQABiDARixAxiABDINCAkQABiDARixAxiABKgCALACAA&sourceid=chrome&ie=UTF-8')

# %%
print(pagina)
# Out:
# <Response [200]>

# %%
print(pagina.content)
# Out:
# b'<!doctype html><html lang="pt-BR"><head><meta charset="UTF-8"><meta content="AmFMpMe9tdD7tYHZ5DTQG/aRAYYkWIQDI/+Hwz5Y7OagTtDB3LA01RMKTpQ8jCqukCmZ7HDuCpEwx7WwAiFBywoAAAByeyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb20uYnI6NDQzIiwiZmVhdHVyZSI6IkxvbmdBbmltYXRpb25GcmFtZVRpbWluZyIsImV4cGlyeSI6MTcwOTY4MzE5OSwiaXNTdWJkb21haW4iOnRydWV9" http-equiv="origin-trial"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>cota\xe7\xe3o dolar - Pesquisa Google</title><script nonce="3kYpjYx7Z75-il9Cl0wDig">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preven
# ...

# %%
sopa = BeautifulSoup(pagina.content,'html.parser')
sopa
# Out:
# <!DOCTYPE html>
# <html lang="pt-BR"><head><meta charset="utf-8"/><meta content="AmFMpMe9tdD7tYHZ5DTQG/aRAYYkWIQDI/+Hwz5Y7OagTtDB3LA01RMKTpQ8jCqukCmZ7HDuCpEwx7WwAiFBywoAAAByeyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb20uYnI6NDQzIiwiZmVhdHVyZSI6IkxvbmdBbmltYXRpb25GcmFtZVRpbWluZyIsImV4cGlyeSI6MTcwOTY4MzE5OSwiaXNTdWJkb21haW4iOnRydWV9" http-equiv="origin-trial"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>cotaçăo dolar - Pesquisa Google</title><script nonce="3kYpjYx7Z75-il9Cl0wDig">(function(){
# ...

# %%
atributos = {'class':'DFlfde SwHCTb'}
sopa.find_all('span', attrs=atributos)
# o beautifulsoup vai fazer uma pesquisa (analise sintatica)
# para encontrar os atributos que possuem a letra g em todas as tags div
# Out:
# []

# %%
sopa.find_all('span', class_='DFlfde SwHCTb')
# Out:
# []
